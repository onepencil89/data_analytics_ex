# %%
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\admin\miniconda3\envs\eda_env\lib\site-packages (6.4.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\admin\miniconda3\envs\eda_env\lib\site-packages (from plotly) (2.11.0)
# Requirement already satisfied: packaging in c:\users\admin\miniconda3\envs\eda_env\lib\site-packages (from plotly) (25.0)

# %%
import plotly.express as px
fig = px.bar(x=["a", "b", "c"], y=[1, 3, 2])
fig.show()

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Create figure with secondary y-axis
fig = make_subplots(specs=[[{"secondary_y": True}]])

# Add traces
fig.add_trace(
    go.Scatter(x=[1, 2, 3], y=[40, 50, 60], name="yaxis data"),
    secondary_y=False,
)

fig.add_trace(
    go.Scatter(x=[2, 3, 4], y=[4, 5, 6], name="yaxis2 data"),
    secondary_y=True,
)

# Add figure title
fig.update_layout(
    title_text="Double Y Axis Example"
)

# Set x-axis title
fig.update_xaxes(title_text="xaxis title")

# Set y-axes titles
fig.update_yaxes(title_text="<b>primary</b> yaxis title", secondary_y=False)
fig.update_yaxes(title_text="<b>secondary</b> yaxis title", secondary_y=True)

fig.show()
