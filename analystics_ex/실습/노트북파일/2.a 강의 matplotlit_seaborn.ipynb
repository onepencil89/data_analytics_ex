# %% [markdown]
# # 데이터 분석 기본 -  시각화

# %% [markdown]
# - matplotlib, seaborn : 정적인 시각화 도구
# - plot : 동적 시각화 도구(interaction 가능)

# %%
# !pip show matplotlib

# %% [markdown]
# ## 기본 plot 그리기

# %%
import matplotlib.pyplot as plt

# %%
# 데이터 준비
import numpy as np
# x :  0, 1, 2, 3, 4, ... 9
# y :  0, 1, 2, 3, 4, ... 9

x = np.arange(0, 9+1)
y = np.arange(0, 9+1)

# %%
# 그래프 그리기
plt.plot(x, y)
plt.show()

# %% [markdown]
# ## Bar Chart

# %%
# !pip install seaborn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
# import seaborn as sns(alias로 sb 또는 sns 보통 사용)

# %%
data_path = '../datas/pokemon.csv'
df = pd.read_csv(data_path)
df.head(5)
# Out:
#    id     species  generation_id  height  weight  base_experience type_1  \
# 0   1   bulbasaur              1     0.7     6.9               64  grass
# 1   2     ivysaur              1     1.0    13.0              142  grass
# 2   3    venusaur              1     2.0   100.0              236  grass
# 3   4  charmander              1     0.6     8.5               62   fire
# 4   5  charmeleon              1     1.1    19.0              142   fire
#
#    type_2  hp  attack  defense  speed  special-attack  special-defense
# 0  poison  45      49       49     45              65               65
# 1  poison  60      62       63     60              80               80
# 2  poison  80      82       83     80             100              100
# 3     NaN  39      52       43     65              60               50
# 4     NaN  58      64       58     80              80               65

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 807 entries, 0 to 806
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               807 non-null    int64
#  1   species          807 non-null    object
#  2   generation_id    807 non-null    int64
#  3   height           807 non-null    float64
#  4   weight           807 non-null    float64
#  5   base_experience  807 non-null    int64
#  6   type_1           807 non-null    object
#  7   type_2           405 non-null    object
#  8   hp               807 non-null    int64
#  9   attack           807 non-null    int64
#  10  defense          807 non-null    int64
#  11  speed            807 non-null    int64
#  12  special-attack   807 non-null    int64
#  13  special-defense  807 non-null    int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 88.4+ KB

# %%
df.columns
# Out:
# Index(['id', 'species', 'generation_id', 'height', 'weight', 'base_experience',
#        'type_1', 'type_2', 'hp', 'attack', 'defense', 'speed',
#        'special-attack', 'special-defense'],
#       dtype='object')

# %%
df['generation_id'].unique()
# Out:
# array([1, 2, 3, 4, 5, 6, 7])

# %%
df['generation_id'].value_counts()
# Out:
# generation_id
# 5    156
# 1    151
# 3    135
# 4    107
# 2    100
# 7     86
# 6     72
# Name: count, dtype: int64

# %%
# 각 세대별로 몇개의 캐릭터가 있는지 시각화 
# 각 데이터의 갯수를 차트로 보여줄수 있는 함수 : sb의 countplot

# %%
df
# Out:
#       id      species  generation_id  height  weight  base_experience  \
# 0      1    bulbasaur              1     0.7     6.9               64
# 1      2      ivysaur              1     1.0    13.0              142
# 2      3     venusaur              1     2.0   100.0              236
# 3      4   charmander              1     0.6     8.5               62
# 4      5   charmeleon              1     1.1    19.0              142
# ..   ...          ...            ...     ...     ...              ...
# 802  803      poipole              7     0.6     1.8              189
# 803  804    naganadel              7     3.6   150.0              243
# 804  805    stakataka              7     5.5   820.0              257
# 805  806  blacephalon              7     1.8    13.0              257
# 806  807      zeraora              7     1.5    44.5              270
#
#        type_1  type_2  hp  attack  defense  speed  special-attack  \
# ...

# %%
# sb.countplot(data= 데이터, x = 데이터내의 칼럼명)
sb.countplot(data=df, x = 'generation_id')

# 폴더가 없으면 자동 생성
folder_path = 'chart_images'
import os
os.makedirs(folder_path, exist_ok = True)

plt.show()
plt.savefig('chart_images/chart03.jpg')

# %% [markdown]
# - countplot은 범주형 데이터를 시각화 할떄 사용

# %%
base_color = sb.color_palette()

# %%
# sb.color_palette()
sb.color_palette()[0]
# Out:
# (0.12156862745098039, 0.4666666666666667, 0.7058823529411765)

# %%
sb.color_palette()[1]
# Out:
# (1.0, 0.4980392156862745, 0.054901960784313725)

# %%
sb.countplot(df, x='generation_id', color=base_color[0])
plt.title("numbers of generations")
plt.show()

# %%
base_order = df['generation_id'].value_counts().index

# %%
sb.countplot(df, x='generation_id', color=base_color[1], order = base_order)
plt.show()

# %%
df
# Out:
#       id      species  generation_id  height  weight  base_experience  \
# 0      1    bulbasaur              1     0.7     6.9               64
# 1      2      ivysaur              1     1.0    13.0              142
# 2      3     venusaur              1     2.0   100.0              236
# 3      4   charmander              1     0.6     8.5               62
# 4      5   charmeleon              1     1.1    19.0              142
# ..   ...          ...            ...     ...     ...              ...
# 802  803      poipole              7     0.6     1.8              189
# 803  804    naganadel              7     3.6   150.0              243
# 804  805    stakataka              7     5.5   820.0              257
# 805  806  blacephalon              7     1.8    13.0              257
# 806  807      zeraora              7     1.5    44.5              270
#
#        type_1  type_2  hp  attack  defense  speed  special-attack  \
# ...

# %%
df['type_1'].value_counts()
# Out:
# type_1
# water       114
# normal      105
# grass        78
# bug          72
# fire         53
# psychic      53
# rock         46
# electric     40
# poison       34
# ground       32
# dark         29
# fighting     29
# dragon       27
# ghost        27
# steel        24
# ice          23
# fairy        18
# flying        3
# Name: count, dtype: int64

# %%
base_order = df['type_1'].value_counts().index
base_order
# Out:
# Index(['water', 'normal', 'grass', 'bug', 'fire', 'psychic', 'rock',
#        'electric', 'poison', 'ground', 'dark', 'fighting', 'dragon', 'ghost',
#        'steel', 'ice', 'fairy', 'flying'],
#       dtype='object', name='type_1')

# %%
sb.countplot(data = df, x = 'type_1', order = base_order, color = base_color[0])
plt.title('numbers of type_1')
plt.xticks(rotation = 90)          # x축의 tick을 90도 화전
plt.show()

# %%
sb.countplot(data= df, y='type_1', order= base_order, color= base_color[4])

plt.show()

# %%
df
# Out:
#       id      species  generation_id  height  weight  base_experience  \
# 0      1    bulbasaur              1     0.7     6.9               64
# 1      2      ivysaur              1     1.0    13.0              142
# 2      3     venusaur              1     2.0   100.0              236
# 3      4   charmander              1     0.6     8.5               62
# 4      5   charmeleon              1     1.1    19.0              142
# ..   ...          ...            ...     ...     ...              ...
# 802  803      poipole              7     0.6     1.8              189
# 803  804    naganadel              7     3.6   150.0              243
# 804  805    stakataka              7     5.5   820.0              257
# 805  806  blacephalon              7     1.8    13.0              257
# 806  807      zeraora              7     1.5    44.5              270
#
#        type_1  type_2  hp  attack  defense  speed  special-attack  \
# ...

# %% [markdown]
# ## pie Chart

# %%
df.columns
# Out:
# Index(['id', 'species', 'generation_id', 'height', 'weight', 'base_experience',
#        'type_1', 'type_2', 'hp', 'attack', 'defense', 'speed',
#        'special-attack', 'special-defense'],
#       dtype='object')

# %%
data = df['generation_id'].value_counts()
data
# Out:
# generation_id
# 5    156
# 1    151
# 3    135
# 4    107
# 2    100
# 7     86
# 6     72
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

plt.rcParams['font.family'] = 'Malgun Gothic' 

plt.pie( 
    data,    # 'generation_id'
    labels = data.index,
    startangle = 45,    # 시계 반대방향으로 각도값 조절.
    wedgeprops={'width':0.6},# 도넛 구멍 ....
    autopct=lambda p: f'{int(round(p * sum(data) / 100))}개'
)
plt.title("세대별 포켓몬 수")
plt.legend(loc = "upper left")
plt.show()

# %% [markdown]
# ## Histogram 시각화

# %%
df
# Out:
#       id      species  generation_id  height  weight  base_experience  \
# 0      1    bulbasaur              1     0.7     6.9               64
# 1      2      ivysaur              1     1.0    13.0              142
# 2      3     venusaur              1     2.0   100.0              236
# 3      4   charmander              1     0.6     8.5               62
# 4      5   charmeleon              1     1.1    19.0              142
# ..   ...          ...            ...     ...     ...              ...
# 802  803      poipole              7     0.6     1.8              189
# 803  804    naganadel              7     3.6   150.0              243
# 804  805    stakataka              7     5.5   820.0              257
# 805  806  blacephalon              7     1.8    13.0              257
# 806  807      zeraora              7     1.5    44.5              270
#
#        type_1  type_2  hp  attack  defense  speed  special-attack  \
# ...

# %%
df['speed'].describe()
# Out:
# count    807.000000
# mean      65.830235
# std       27.736838
# min        5.000000
# 25%       45.000000
# 50%       65.000000
# 75%       85.000000
# max      160.000000
# Name: speed, dtype: float64

# %%
plt.hist(data = df , x = 'speed', rwidth = 0.85)
plt.show()

# %%
plt.hist(data = df, 
         x = 'speed', 
         rwidth = 0.85, # 맥대의 굵기를 설정
         bins =20       # 막대의 갯수를 설정
)

# %% [markdown]
# ## figures, Axes and Subplots

# %%
#다수의 차트를 한 영역에 그리는 방법

# %%
plt.figure( figsize = (10,4))

plt.subplot(1,2,1)  # 차트영역을, 1행 2열로 만들어서 첫번째 영역에 그려라.

plt.hist(data = df, x = 'speed', rwidth = 0.9, bins = 10)
plt.title('스피드 hist 10개 구간')
plt.xlabel('스피드')
plt.ylabel('갯수')

plt.subplot(1,2,2)

plt.hist(data = df, x = 'speed', rwidth = 0.9, bins = 20)
plt.title('스피드 hist 20개 구간')
plt.xlabel('스피드')
plt.ylabel('갯수')

plt.savefig('chart_images/chart02.jpg')
plt.show()

# %% [markdown]
# ## 다수의 plot 그리기

# %% [markdown]
# ### data loading

# %%
data_path = '../datas/fuel_econ.csv'

df = pd.read_csv(data_path)

# %%
df.columns
# Out:
# Index(['id', 'make', 'model', 'year', 'VClass', 'drive', 'trans', 'fuelType',
#        'cylinders', 'displ', 'pv2', 'pv4', 'city', 'UCity', 'highway',
#        'UHighway', 'comb', 'co2', 'feScore', 'ghgScore'],
#       dtype='object')

# %%
df.corr(numeric_only=True)
# Out:
#                  id      year  cylinders     displ       pv2       pv4  \
# id         1.000000  0.985668  -0.060096 -0.074666 -0.006569 -0.021951
# year       0.985668  1.000000  -0.055313 -0.070424  0.006232 -0.033643
# cylinders -0.060096 -0.055313   1.000000  0.933872  0.247571 -0.004264
# displ     -0.074666 -0.070424   0.933872  1.000000  0.259336  0.022072
# pv2       -0.006569  0.006232   0.247571  0.259336  1.000000 -0.665642
# pv4       -0.021951 -0.033643  -0.004264  0.022072 -0.665642  1.000000
# city       0.091800  0.068050  -0.693103 -0.713479 -0.278109  0.035188
# UCity      0.091225  0.066742  -0.666029 -0.686166 -0.272546  0.037869
# highway    0.090593  0.073290  -0.766275 -0.783984 -0.296808  0.074952
# UHighway   0.095359  0.077641  -0.771503 -0.788457 -0.298504  0.077442
# comb       0.093803  0.071993  -0.738023 -0.758397 -0.290883  0.047333
# co2       -0.099717 -0.081165   0.848274  0.855375  0.287200 -0.050153
# ...

# %%
# 배기량과 복하변비의 corr
df[['displ','comb']].corr()
# Out:
#           displ      comb
# displ  1.000000 -0.758397
# comb  -0.758397  1.000000

# %%
df.head()
# Out:
#       id        make           model  year           VClass  \
# 0  32204      Nissan            GT-R  2013  Subcompact Cars
# 1  32205  Volkswagen              CC  2013     Compact Cars
# 2  32206  Volkswagen              CC  2013     Compact Cars
# 3  32207  Volkswagen      CC 4motion  2013     Compact Cars
# 4  32208   Chevrolet  Malibu eAssist  2013     Midsize Cars
#
#                drive              trans          fuelType  cylinders  displ  \
# 0    All-Wheel Drive    Automatic (AM6)  Premium Gasoline          6    3.8
# 1  Front-Wheel Drive  Automatic (AM-S6)  Premium Gasoline          4    2.0
# 2  Front-Wheel Drive     Automatic (S6)  Premium Gasoline          6    3.6
# 3    All-Wheel Drive     Automatic (S6)  Premium Gasoline          6    3.6
# 4  Front-Wheel Drive     Automatic (S6)  Regular Gasoline          4    2.4
#
#    pv2  pv4     city    UCity  highway  UHighway     comb  co2  feScore  \
# ...

# %%
plt.scatter(data = df, x='displ' ,y='comb')
plt.title('배기량 - 복합연비 산점도')
plt.xlabel('배기량')
plt.ylabel('복합연비')
plt.show()

# %%
# 회기선 regression.
sb.regplot(data=df, x='displ' ,y='comb')
plt.show()

# %%
df[['displ','comb']].corr()
# Out:
#           displ      comb
# displ  1.000000 -0.758397
# comb  -0.758397  1.000000

# %%
sb.pairplot(data= df,  vars= ['displ', 'comb', 'co2' ] )
plt.show()

# %% [markdown]
# ### HEAT MAP

# %%
flights_df = sb.load_dataset("flights")
flights_df.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB

# %%
pivot_df = flights_df.pivot(index='month', columns='year', values='passengers')
pivot_df
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
sb.heatmap(pivot_df)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
plt.hist2d(data= df, x='displ', y='comb', cmin=0.5, cmap='viridis_r', bins=20)
plt.colorbar()
plt.title('배기량과 연비의 관계')
plt.xlabel('배기량')
plt.ylabel('연비')
plt.show()

# %% [markdown]
# ### 문제 1. 위에서 city 와 highway 에서의 연비 관계를 분석하세요.

# %%
df.columns
# Out:
# Index(['id', 'make', 'model', 'year', 'VClass', 'drive', 'trans', 'fuelType',
#        'cylinders', 'displ', 'pv2', 'pv4', 'city', 'UCity', 'highway',
#        'UHighway', 'comb', 'co2', 'feScore', 'ghgScore'],
#       dtype='object')

# %%
plt.scatter(data = df , x = 'city', y = 'highway')
plt.title('도심-고속도로 연비 관계도')
plt.xlabel('city')
plt.xlabel('highway')
plt.show()

# %%
df[['city','highway']].corr()
# Out:
#              city   highway
# city     1.000000  0.915435
# highway  0.915435  1.000000

# %% [markdown]
# ### 문제 2. 엔진 크기와 이산화탄소 배출량의 관계를 분석하세요.
# - (히트맵으로) displ 이 엔진사이즈이고, co2 가 이산화탄소 배출량입니다. 트랜드를 분석하세요

# %%
df.columns
# Out:
# Index(['id', 'make', 'model', 'year', 'VClass', 'drive', 'trans', 'fuelType',
#        'cylinders', 'displ', 'pv2', 'pv4', 'city', 'UCity', 'highway',
#        'UHighway', 'comb', 'co2', 'feScore', 'ghgScore'],
#       dtype='object')

# %%
df[['displ','co2']].corr()
# Out:
#           displ       co2
# displ  1.000000  0.855375
# co2    0.855375  1.000000

# %%
plt.hist2d(data = df , x = 'displ', y = 'co2',cmin=0.3, cmap='viridis_r', bins=30)
plt.colorbar()
plt.title('배기량-이산화탄소 배출량 관계도')
plt.xlabel('배기량')
plt.ylabel('이산화탄소 배출량')
plt.show()

# %% [markdown]
# ### 3. displ 배출량의 이상치 확인
# - seaborn의 박스플랏
# - displ 컬럼의 데이터에 이상치가 있는지 확인하기

# %%
sb.boxplot(x = df['displ'])
plt.xlabel('배기량 boxplot')
plt.show()
